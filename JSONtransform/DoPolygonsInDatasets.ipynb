# %%
import os
import polylinesToPolygonJSON
ROOT_DIR = os.path.abspath("../../")

# %%
#transform anotations of training dataset
PATH_TRAIN_in = os.path.join(ROOT_DIR,'Mask_RCNN/datasets/treering/train/via_region_data.json')
PATH_TRAIN_out = os.path.join(ROOT_DIR,'Mask_RCNN/datasets/treering/train/via_region_data_transformed.json')

polylinesToPolygonJSON.linesToPolygons(input = PATH_TRAIN_in, output = PATH_TRAIN_out)
# Out:
# {'0002026B1-Image Export-04.jpg1377004': {'filename': '0002026B1-Image Export-04.jpg',
#   'size': 1377004,
#   'regions': [{'shape_attributes': {'name': 'polygon',
#      'all_points_x': [192,
#       178,
#       166,
#       161,
#       164,
#       166,
#       160,
#       146,
#       143,
#       143,
#       142,
#       142,
#       135,
#       147,
#       159,
#       165,
#       170,
#       179,
#       173,
#       170,
#       186,
#       192,
#       181,
#       186,
#       192,
#       195,
#       188,
#       191,
#       191,
#       191,
#       192,
#       525,
#       518,
#       515,
#       513,
#       508,
#       500,
#       490,
#       484,
#       491,
#       498,
#       499,
#       502,
#       496,
#       498,
#       502,
#       493,
#       484,
#       478,
#       473,
#       469,
#       478,
#       473,
#       466,
#       469,
#       455,
#       442,
#       454,
#       473,
#       477,
#       475,
#       487,
# ...

# %%
#transform anotations of validation dataset
PATH_TRAIN_in = os.path.join(ROOT_DIR,'Mask_RCNN/datasets/treering/val/via_region_data.json')
PATH_TRAIN_out = os.path.join(ROOT_DIR,'Mask_RCNN/datasets/treering/val/via_region_data_transformed.json')

# %%
PATH_TRAIN_in
# Out:
# '/Users/miroslav.polacek/Dropbox (VBC)/Group Folder Swarts/Research/CNNRings/Mask_RCNN/datasets/treering/train/via_region_data.json'

# %%
cd /Users/miroslav.polacek/Dropbox\ \(VBC\)/'Group Folder Swarts'/Research/CNNRings/Mask_RCNN/samples/balloon

# %%
python3 balloon.py train --dataset= /Users/miroslav.polacek/Dropbox\ \(VBC\)/'Group Folder Swarts'/Research/CNNRings/Mask_RCNN/datasets/treering
 --weights=imagenet
